# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'main.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
df_csv = pandas.read_csv("supermarkets.csv")
df_csv.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json = pandas.read_json("supermarkets.json")
df_json.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_xls = pandas.read_excel("supermarkets.xlsx")
df_xls
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df_txt = pandas.read_csv("supermarkets-commas.txt")
df_txt.columns = ["ID", "Address", "City", "State", "Country", "Name", "Peoples"]
df_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Peoples
# 0        8
# 1       15
# 2       25
# 3       10
# 4       12
# 5       20

# %%
df = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df.set_index("ID", inplace=True)
df
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
list(df.loc["1":"1", "City"])
# Out:
# ['San Francisco']

# %%
df
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.iloc[0:3,1:6]
# Out:
#              City             State Country          Name  Employees
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25

# %%
df.iloc[3,4]
# Out:
# "Ben's Shop"

# %%
df.drop(df.columns[0:3], 1)
# Out:
#    Country          Name  Employees
# ID
# 1      USA       Madeira          8
# 2      USA   Bready Shop         15
# 3      USA   Super River         25
# 4      USA    Ben's Shop         10
# 5      USA       Sanchez         12
# 6      USA    Richvalley         20

# %%
df.drop(df.columns[-5],1)
# Out:
#             Address             State Country          Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA       Madeira          8
# 2    735 Dolores St          CA 94119     USA   Bready Shop         15
# 3       332 Hill St  California 94114     USA   Super River         25
# 4      3995 23rd St          CA 94114     USA    Ben's Shop         10
# 5   1056 Sanchez St        California     USA       Sanchez         12
# 6   551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
df = df.drop(df.columns[-2],1)
df
# Out:
#                           City             State Country      Continent
# Address
# 3666 21st St     San Francisco          CA 94114     USA  North America
# 735 Dolores St   San Francisco          CA 94119     USA  North America
# 332 Hill St      San Francisco  California 94114     USA  North America
# 3995 23rd St     San Francisco          CA 94114     USA  North America
# 1056 Sanchez St  San Francisco        California     USA  North America
# 551 Alvarado St  San Francisco          CA 94114     USA  North America

# %%
df["ID"] = ["1","2","3","4","5","6"]
df["Employess"] = ["8", "15","25", "10", "12", "20"]
df["Name"] = ['Madeira', 'Bready Shop',"Super River", "Ben's Shop","Sanchez", "Richvalley"]
df
# Out:
#                           City             State Country      Continent ID  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA  North America  1
# 735 Dolores St   San Francisco          CA 94119     USA  North America  2
# 332 Hill St      San Francisco  California 94114     USA  North America  3
# 3995 23rd St     San Francisco          CA 94114     USA  North America  4
# 1056 Sanchez St  San Francisco        California     USA  North America  5
# 551 Alvarado St  San Francisco          CA 94114     USA  North America  6
#
#                 Employess         Name
# Address
# 3666 21st St            8      Madeira
# 735 Dolores St         15  Bready Shop
# 332 Hill St            25  Super River
# 3995 23rd St           10   Ben's Shop
# 1056 Sanchez St        12      Sanchez
# 551 Alvarado St        20   Richvalley

# %%
df.shape[0]
# Out:
# 6

# %%
df["Continent"] = df["Country"]
df
# Out:
#                           City             State Country Continent ID  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA       USA  1
# 735 Dolores St   San Francisco          CA 94119     USA       USA  2
# 332 Hill St      San Francisco  California 94114     USA       USA  3
# 3995 23rd St     San Francisco          CA 94114     USA       USA  4
# 1056 Sanchez St  San Francisco        California     USA       USA  5
# 551 Alvarado St  San Francisco          CA 94114     USA       USA  6
#
#                 Employess         Name
# Address
# 3666 21st St            8      Madeira
# 735 Dolores St         15  Bready Shop
# 332 Hill St            25  Super River
# 3995 23rd St           10   Ben's Shop
# 1056 Sanchez St        12      Sanchez
# 551 Alvarado St        20   Richvalley

# %%
df_t = df.T

# %%
df_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Continent            USA            USA               USA            USA
# ID                     1              2                 3              4
# Employess              8             15                25             10
# Name             Madeira    Bready Shop       Super River     Ben's Shop
#
# Address   1056 Sanchez St 551 Alvarado St
# City        San Francisco   San Francisco
# State          California        CA 94114
# Country               USA             USA
# Continent             USA             USA
# ID                      5               6
# Employess              12              20
# Name              Sanchez      Richvalley

# %%
df_t["Rua joao artoni testae"] = ["Guarulhos", "Sao Paulo", 'Brazil',"South America", '7', '5','Blacks']
df_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Continent            USA            USA               USA            USA
# ID                     1              2                 3              4
# Employess              8             15                25             10
# Name             Madeira    Bready Shop       Super River     Ben's Shop
#
# Address   1056 Sanchez St 551 Alvarado St Rua joao artoni testae
# City        San Francisco   San Francisco              Guarulhos
# State          California        CA 94114              Sao Paulo
# Country               USA             USA                 Brazil
# Continent             USA             USA          South America
# ...

# %%
df = df_t.T

# %%
df
# Out:
#                                  City             State Country  \
# Address
# 3666 21st St            San Francisco          CA 94114     USA
# 735 Dolores St          San Francisco          CA 94119     USA
# 332 Hill St             San Francisco  California 94114     USA
# 3995 23rd St            San Francisco          CA 94114     USA
# 1056 Sanchez St         San Francisco        California     USA
# 551 Alvarado St         San Francisco          CA 94114     USA
# Rua joao artoni testae      Guarulhos         Sao Paulo  Brazil
#
#                             Continent ID Employess         Name
# Address
# 3666 21st St                      USA  1         8      Madeira
# 735 Dolores St                    USA  2        15  Bready Shop
# 332 Hill St                       USA  3        25  Super River
# 3995 23rd St                      USA  4        10   Ben's Shop
# 1056 Sanchez St                   USA  5        12      Sanchez
# ...
